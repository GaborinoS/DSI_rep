# %%
#!python3
import pymongo
from pymongo import MongoClient
#import dnspython
from tabulate import tabulate
import ssl
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 5
#       3 from pymongo import MongoClient
#       4 #import dnspython
# ----> 5 from tabulate import tabulate
#       6 import ssl
#       7 import pandas as pd
#
# ModuleNotFoundError: No module named 'tabulate'

# %%
client = MongoClient('mongodb+srv://student:nRfKfRqEtgWvznFD@cluster0.gu4ru.mongodb.net')

# %%
db = client.get_database('sample_airbnb')

# %%
rbnb = db.listingsAndReviews.find()

# %%
rbnb_df = pd.DataFrame(rbnb)

# %%
rbnb_df.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10047964  https://www.airbnb.com/rooms/10047964
# 2  10109896  https://www.airbnb.com/rooms/10109896
# 3  10006546  https://www.airbnb.com/rooms/10006546
# 4  10057826  https://www.airbnb.com/rooms/10057826
#
#                                   name  \
# 0  New York City - Upper West Side Apt
# 1       Charming Flat in Downtown Moda
# 2  THE Place to See Sydney's FIREWORKS
# 3              Ribeira Charming Duplex
# 4                    Deluxe Loft Suite
#
#                                              summary  \
# 0
# 1  Fully furnished 3+1 flat decorated with vintag...
# 2  The ultimate way to experience Sydney Harbour;...
# 3  Fantastic duplex apartment with three bedrooms...
# 4  Loft Suite Deluxe @ Henry Norman Hotel Located...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# 1  The apartment is composed of 1 big bedroom wit...
# 2  An entertainer's retreat!!  Views of the Sydne...
# 3  Privileged views of the Douro River and Ribeir...
# 4  This loft unit features a kitchenette and is f...
#
#                                          description  \
# 0  Murphy bed, optional second bedroom available....
# 1  Fully furnished 3+1 flat decorated with vintag...
# 2  The ultimate way to experience Sydney Harbour;...
# 3  Fantastic duplex apartment with three bedrooms...
# 4  Loft Suite Deluxe @ Henry Norman Hotel Located...
#
#                                neighborhood_overview  \
# 0  Great neighborhood - many terrific restaurants...
# 1  With its diversity Moda- Kadikoy is one of the...
# 2  We're 5 minutes from the bus stops (to the cit...
# 3  In the neighborhood of the river, you can find...
# 4  Greenpoint is an artsy Brooklyn neighborhood f...
#
#                                                notes  \
# 0  My cat, Samantha, are in and out during the su...
# 1
# 2  We live with our stud dog, and our son; we won...
# 3  Lose yourself in the narrow streets and stairc...
# 4
#
#                                              transit  \
# 0  Conveniently located near 1, 2, 3, B & C subwa...
# 1
# 2  Parking is available on the street in front or...
# 3  Transport: • Metro station and S. Bento railwa...
# 4
#
#                                               access  ... guests_included  \
# 0                                     New York City!  ...               1
# 1                                                     ...               1
# 2  You'll access all areas except the master bedr...  ...               1
# 3  We are always available to help guests. The ho...  ...               6
# 4  Guest will have access to common terraces, lou...  ...               1
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '454250', 'host_url': 'https://www...
# 1  {'host_id': '1241644', 'host_url': 'https://ww...
# 2  {'host_id': '6517277', 'host_url': 'https://ww...
# 3  {'host_id': '51399391', 'host_url': 'https://w...
# 4  {'host_id': '47554473', 'host_url': 'https://w...
#
#                                              address  \
# 0  {'street': 'New York, NY, United States', 'sub...
# 1  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 2  {'street': 'Rozelle, NSW, Australia', 'suburb'...
# 3  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 4  {'street': 'Brooklyn, NY, United States', 'sub...
#
#                                         availability  \
# 0  {'availability_30': 0, 'availability_60': 0, '...
# 1  {'availability_30': 27, 'availability_60': 57,...
# 2  {'availability_30': 0, 'availability_60': 0, '...
# 3  {'availability_30': 28, 'availability_60': 47,...
# 4  {'availability_30': 30, 'availability_60': 31,...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
# 1  {'review_scores_accuracy': 10, 'review_scores_...
# 2                                                 {}
# 3  {'review_scores_accuracy': 9, 'review_scores_c...
# 4  {'review_scores_accuracy': 9, 'review_scores_c...
#
#                                              reviews weekly_price  \
# 0  [{'_id': '4351675', 'date': 2013-04-29 04:00:0...          NaN
# 1  [{'_id': '68162172', 'date': 2016-04-02 04:00:...          NaN
# 2                                                 []          NaN
# 3  [{'_id': '58663741', 'date': 2016-01-03 05:00:...          NaN
# 4  [{'_id': '58665374', 'date': 2016-01-03 05:00:...          NaN
#
#   monthly_price reviews_per_month
# 0           NaN               NaN
# 1           NaN               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN
#
# [5 rows x 42 columns]
