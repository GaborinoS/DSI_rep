# %% [markdown]
# # Assignment Part One
# You are free choose whether to solve the following exercises in MQL or to write the queries in python using <a href='https://pymongo.readthedocs.io/en/stable/'>pymongo</a>

# %%
#!python3
import pymongo
from pymongo import MongoClient
#import dnspython
from tabulate import tabulate
import ssl
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
client = MongoClient('mongodb+srv://student:nRfKfRqEtgWvznFD@cluster0.gu4ru.mongodb.net')
db = client.get_database('sample_airbnb')
rbnb = db.listingsAndReviews.find()
rbnb_df = pd.DataFrame(rbnb)

# %% [markdown]
# ## Airbnb Dataset

# %% [markdown]
# What is the name of the listing in the sample_airbnb.listingsAndReviews dataset
# that accommodates more than 6 people and has exactly 50 reviews

# %%
rbnb_df[(rbnb_df['accommodates']>6) & ([len(x)==50 for x in rbnb_df['reviews']])]

#[len(x)==50 for x in rbnb_df['reviews']]
# Out:
#           _id                           listing_url  \
# 4525  4294289  https://www.airbnb.com/rooms/4294289
#
#                             name  \
# 4525  Sunset Beach Lodge Retreat
#
#                                                 summary  \
# 4525  Large 3 bedrooms, 2 bathrooms with Office Spac...
#
#                                                   space  \
# 4525  This amazing lodge style home is one of da kin...
#
#                                             description  \
# 4525  Large 3 bedrooms, 2 bathrooms with Office Spac...
#
#                                   neighborhood_overview  \
# 4525  Sunset Beach area is one of the prestigious pl...
#
#                                 notes transit  \
# 4525  (Phone number hidden by Airbnb)
#
#                                       access  ...  \
# 4525  The entire upstairs unit. Parking Lot.  ...
#
#                                                    host  \
# 4525  {'host_id': '13508451', 'host_url': 'https://w...
#
#                                                 address  \
# 4525  {'street': 'Haleiwa, HI, United States', 'subu...
#
#                                            availability  \
# 4525  {'availability_30': 6, 'availability_60': 28, ...
#
#                                           review_scores  \
# 4525  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                                 reviews security_deposit  \
# 4525  [{'_id': '31113473', 'date': 2015-05-02 04:00:...           500.00
#
#      cleaning_fee weekly_price monthly_price reviews_per_month
# 4525       300.00          NaN           NaN               NaN
#
# [1 rows x 42 columns]

# %% [markdown]
# Using the sample_airbnb.listingsAndReviews collection find out how many
# documents have the "property_type" "House", and include "Changing table" as
# one of the "amenities"?

# %%
rbnb_df[([('Changing table' in x) for x in rbnb_df['amenities']])& (rbnb_df['property_type'] == 'House')]
# Out:
#            _id                            listing_url  \
# 1080  15893952  https://www.airbnb.com/rooms/15893952
# 1096  15997148  https://www.airbnb.com/rooms/15997148
# 1106  16029413  https://www.airbnb.com/rooms/16029413
# 1152  16253247  https://www.airbnb.com/rooms/16253247
# 1251  16885508  https://www.airbnb.com/rooms/16885508
# 1703  19572281  https://www.airbnb.com/rooms/19572281
# 1947  20206764  https://www.airbnb.com/rooms/20206764
# 2292  22005432  https://www.airbnb.com/rooms/22005432
# 2426  22396955  https://www.airbnb.com/rooms/22396955
# 4517   3963635   https://www.airbnb.com/rooms/3963635
# 4786   5307830   https://www.airbnb.com/rooms/5307830
#
#                                                    name  \
# 1080           Modern, Quiet Semi stroll to Manly Beach
# 1096  Huge kid-friendly Brooklyn home with parking/p...
# 4786  *State of Hawaii Taxes  - General Excise Tax (...
#
#                                                 transit  \
# 1080  Our house is only a short walk to the beach, r...
# 1096
# 1106  Once in Bundeena, you really don't need a car ...
# 1152  Proximity to Airports: Surf Temple is just twe...
# 1251  There is always lots of street parking availab...
# 1703  Estacionamento fácil na via pública, em frente...
# 1947          Walking Uber or Taxi Bus stop 1-2min walk
# 2292  The bus stop is a 1 minute walk.  There is on ...
# 2426  There’s a wide range of transports near the ho...
# 4517  The apartment is in walking distance to a seve...
# 4786  We have our own fleet of vehicles, which inclu...
#
#                                                  access  ...  \
# 1080                                                     ...
# 1096                                                     ...
# 1106  We prefer someone to be here when you arrive, ...  ...
# 1152  Guests will have access to the entire house! T...  ...
# 1251  Everywhere except the back garden below the de...  ...
# 1703                            Livre acesso à cozinha.  ...
# 1947                          Entire place as described  ...
# 2292  In addition to great quality linen, we provide...  ...
# 2426  The house is all available for the private use...  ...
# 4517  Hosts Pervaiz & Laena live in the apartment wi...  ...
# 4786  Entire space is included in this rental. Pleas...  ...
#
#                                                    host  \
# 1080  {'host_id': '85391052', 'host_url': 'https://w...
# 1096  {'host_id': '200060', 'host_url': 'https://www...
# 1106  {'host_id': '104281282', 'host_url': 'https://...
# 1152  {'host_id': '106070244', 'host_url': 'https://...
# 1251  {'host_id': '103281975', 'host_url': 'https://...
# 1703  {'host_id': '88573374', 'host_url': 'https://w...
# 1947  {'host_id': '10462547', 'host_url': 'https://w...
# 2292  {'host_id': '1879921', 'host_url': 'https://ww...
# 2426  {'host_id': '163147652', 'host_url': 'https://...
# 4517  {'host_id': '20543178', 'host_url': 'https://w...
# 4786  {'host_id': '24671259', 'host_url': 'https://w...
#
#                                                 address  \
# 1080  {'street': 'Manly, NSW, Australia', 'suburb': ...
# 1096  {'street': 'Brooklyn, NY, United States', 'sub...
# 1106  {'street': 'Bundeena, NSW, Australia', 'suburb...
# 1152  {'street': 'Kailua-Kona, HI, United States', '...
# 1251  {'street': 'Saint Ives, NSW, Australia', 'subu...
# 1703  {'street': 'Vila Nova da Telha, Porto, Portuga...
# 1947  {'street': 'Bronte, NSW, Australia', 'suburb':...
# 2292  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 2426  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 4517  {'street': 'Brooklyn , NY, United States', 'su...
# 4786  {'street': 'Honolulu, HI, United States', 'sub...
#
#                                            availability  \
# 1080  {'availability_30': 0, 'availability_60': 0, '...
# 1096  {'availability_30': 0, 'availability_60': 0, '...
# 1106  {'availability_30': 22, 'availability_60': 43,...
# 1152  {'availability_30': 5, 'availability_60': 11, ...
# 1251  {'availability_30': 0, 'availability_60': 15, ...
# 1703  {'availability_30': 15, 'availability_60': 35,...
# 1947  {'availability_30': 0, 'availability_60': 5, '...
# 2292  {'availability_30': 0, 'availability_60': 10, ...
# 2426  {'availability_30': 19, 'availability_60': 41,...
# 4517  {'availability_30': 0, 'availability_60': 0, '...
# 4786  {'availability_30': 0, 'availability_60': 0, '...
#
#                                           review_scores  \
# 1080  {'review_scores_accuracy': 10, 'review_scores_...
# 1096  {'review_scores_accuracy': 10, 'review_scores_...
# 1106  {'review_scores_accuracy': 10, 'review_scores_...
# 1152  {'review_scores_accuracy': 10, 'review_scores_...
# 1251  {'review_scores_accuracy': 10, 'review_scores_...
# 1703  {'review_scores_accuracy': 10, 'review_scores_...
# 1947  {'review_scores_accuracy': 10, 'review_scores_...
# 2292  {'review_scores_accuracy': 10, 'review_scores_...
# 2426  {'review_scores_accuracy': 10, 'review_scores_...
# 4517  {'review_scores_accuracy': 9, 'review_scores_c...
# 4786  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                                 reviews security_deposit  \
# 1080  [{'_id': '116696041', 'date': 2016-12-02 05:00...           500.00
# 1096  [{'_id': '115682030', 'date': 2016-11-26 05:00...              NaN
# 1106  [{'_id': '130150920', 'date': 2017-02-04 05:00...           500.00
# 1152  [{'_id': '124406978', 'date': 2017-01-01 05:00...           100.00
# 1251  [{'_id': '194980560', 'date': 2017-09-17 04:00...           500.00
# 1703  [{'_id': '182392512', 'date': 2017-08-14 04:00...             0.00
# 1947  [{'_id': '194394612', 'date': 2017-09-16 04:00...           750.00
# 2292  [{'_id': '223835129', 'date': 2018-01-01 05:00...          1000.00
# 2426  [{'_id': '247693704', 'date': 2018-03-29 04:00...             0.00
# 4517  [{'_id': '40264452', 'date': 2015-07-29 04:00:...             0.00
# 4786  [{'_id': '198007203', 'date': 2017-09-27 04:00...           300.00
#
#      cleaning_fee weekly_price monthly_price reviews_per_month
# 1080       100.00          NaN           NaN               NaN
# 1096          NaN          NaN           NaN               NaN
# 1106       120.00          NaN           NaN               NaN
# 1152       200.00          NaN           NaN               NaN
# 1251        85.00          NaN           NaN               NaN
# 1703         0.00          NaN           NaN               NaN
# 1947        95.00          NaN           NaN               NaN
# 2292       250.00          NaN           NaN               NaN
# 2426        20.00          NaN           NaN               NaN
# 4517       100.00          NaN           NaN               NaN
# 4786       495.00          NaN           NaN               NaN
#
# [11 rows x 42 columns]

# %% [markdown]
# What room types are present in the sample_airbnb.listingsAndReviews collection?

# %%
np.unique(rbnb_df['room_type'])
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %% [markdown]
# ## Mflix Dataset

# %% [markdown]
# (following exercise may be easier in python)
# Our movies dataset has a lot of different documents, some with more convoluted titles than
# others.
# Find the count of the number of movies that have a title composed of one word.
# To clarify, "Cinderella" and "3-25" should count, where as "Cast Away" would not.
#
# You may want to take look into the `$split` String expression and the `$size` Array expression
#
# * https://docs.mongodb.com/manual/reference/operator/aggregation/split/
# * https://docs.mongodb.com/manual/reference/operator/aggregation/size/
# * https://database.guide/mongodb-split/
# * https://pymongo.readthedocs.io/en/stable/examples/aggregation.html

# %%
db = client.get_database('sample_mflix')
movies = db.movies.find()
movies_df = pd.DataFrame(movies)
movies_df.head()
# Out:
#                         _id  \
# 0  573a1390f29313caabcd446f
# 1  573a1390f29313caabcd4803
# 2  573a1390f29313caabcd4eaf
# 3  573a1390f29313caabcd516c
# 4  573a1390f29313caabcd5293
#
#                                                 plot  \
# 0  A greedy tycoon decides, on a whim, to corner ...
# 1  Cartoon figures announce, via comic strip ball...
# 2  A woman, with the aid of her police officer sw...
# 3  Original advertising for the film describes it...
# 4  Young Pauline is left a lot of money when her ...
#
#                        genres  runtime  \
# 0              [Short, Drama]     14.0
# 1  [Animation, Short, Comedy]      7.0
# 2              [Crime, Drama]     88.0
# 3            [Drama, History]     65.0
# 4                    [Action]    199.0
#
#                                                 cast  num_mflix_comments  \
# 0  [Frank Powell, Grace Henderson, James Kirkwood...                   1
# 1                                     [Winsor McCay]                   0
# 2  [Jane Gail, Ethel Grandin, William H. Turner, ...                   1
# 3  [Stanley Hunt, Sarah Constance Smith Hunt, Mrs...                   1
# 4  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...                   0
#
#                                                title  \
# 0                                  A Corner in Wheat
# 1  Winsor McCay, the Famous Cartoonist of the N.Y...
# 2                                   Traffic in Souls
# 3                    In the Land of the Head Hunters
# 4                              The Perils of Pauline
#
#                                             fullplot  languages   released  \
# 0  A greedy tycoon decides, on a whim, to corner ...  [English] 1909-12-13
# 1  Cartoonist Winsor McCay agrees to create a lar...  [English] 1911-04-08
# 2                                                NaN  [English] 1913-11-24
# 3                                                NaN  [English] 1914-12-07
# 4  Young Pauline is left a lot of money when her ...  [English] 1914-03-23
#
#    ...                                           awards  \
# 0  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 1  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 4  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
#
#                      lastupdated  year  \
# 0  2015-08-13 00:46:30.660000000  1909
# 1  2015-08-29 01:09:03.030000000  1911
# 2  2015-09-15 02:07:14.247000000  1913
# 3  2015-09-16 12:11:37.770000000  1914
# 4  2015-09-12 00:01:18.647000000  1914
#
#                                          imdb countries   type  \
# 0   {'rating': 6.6, 'votes': 1375, 'id': 832}     [USA]  movie
# 1  {'rating': 7.3, 'votes': 1034, 'id': 1737}     [USA]  movie
# 2   {'rating': 6.0, 'votes': 371, 'id': 3471}     [USA]  movie
# 3   {'rating': 5.8, 'votes': 223, 'id': 4150}     [USA]  movie
# 4   {'rating': 7.6, 'votes': 744, 'id': 4465}     [USA]  movie
#
#                                             tomatoes  \
# 0  {'viewer': {'rating': 3.6, 'numReviews': 109, ...
# 1  {'viewer': {'rating': 3.4, 'numReviews': 89, '...
# 2  {'viewer': {'rating': 3.0, 'numReviews': 85, '...
# 3  {'viewer': {'rating': 2.7, 'numReviews': 64, '...
# 4  {'viewer': {'rating': 2.8, 'numReviews': 9}, '...
#
#                                               poster  \
# 0                                                NaN
# 1  https://m.media-amazon.com/images/M/MV5BYzg2Nj...
# 2  https://m.media-amazon.com/images/M/MV5BYzk0YW...
# 3  https://m.media-amazon.com/images/M/MV5BMjE3Mj...
# 4  https://m.media-amazon.com/images/M/MV5BMzgxOD...
#
#                                              writers metacritic
# 0                                                NaN        NaN
# 1  [Winsor McCay (comic strip "Little Nemo in Slu...        NaN
# 2                                                NaN        NaN
# 3                         [Edward S. Curtis (story)]        NaN
# 4  [Charles W. Goddard (screenplay), Basil Dickey...        NaN
#
# [5 rows x 22 columns]

# %%
movies_df[movies_df.loc[:,'title'].str.contains('.\s.') == False]
# Out:
#                             _id  \
# 13     573a1391f29313caabcd7616
# 23     573a1391f29313caabcd8780
# 24     573a1391f29313caabcd8945
# 26     573a1391f29313caabcd8979
# 27     573a1391f29313caabcd89aa
# ...                         ...
# 23506  573a13f6f29313caabde568a
# 23507  573a13f6f29313caabde5900
# 23515  573a13f7f29313caabde74cd
# 23518  573a13f9f29313caabde9a81
# 23525  573a13faf29313caabdeba84
#
#                                                     plot  \
# 13     Salome, the daughter of Herodias, seduces her ...
# 23     A salesgirl with plenty of "it" (sex appeal) p...
# 24     A married farmer falls under the spell of a sl...
# 26     Among the residents of a theatrical boarding h...
# 27     Two young men, one rich, one middle class, who...
# ...                                                  ...
# 23506  The "manager" of a pancake stall finds himself...
# 23507  When the ship's owner goes bankrupt, the crew ...
# 23515                                                NaN
# 23518                                                NaN
# 23525  A man who supposley killed his family hides at...
#
#                             genres  runtime  \
# 13     [Biography, Drama, History]     72.0
# 23               [Comedy, Romance]     72.0
# 24                [Drama, Romance]     94.0
# 26                 [Comedy, Drama]     60.0
# 27           [Drama, Romance, War]    144.0
# ...                            ...      ...
# 23506                      [Drama]    113.0
# 23507                      [Drama]    104.0
# 23515                      [Drama]    127.0
# 23518                          NaN     71.0
# 23525                   [Thriller]    111.0
#
#                                                     cast  num_mflix_comments  \
# 13     [Mitchell Lewis, Alla Nazimova, Rose Dione, Ea...                   0
# 23     [Clara Bow, Antonio Moreno, William Austin, Pr...                   1
# 24     [George O'Brien, Janet Gaynor, Margaret Living...                   0
# 26     [Nancy Nash, Earle Foxe, Grant Withers, Lydia ...                   3
# 27     [Clara Bow, Charles 'Buddy' Rogers, Richard Ar...                   1
# ...                                                  ...                 ...
# 23506  [Kirin Kiki, Miyoko Asada, Etsuko Ichihara, Mi...                   1
# 23507  [Nadir Saribacak, Hakan Karsak, Kadir Cermik, ...                   2
# 23515  [Catherine Frot, Andrè Marcon, Denis Mpunga, M...                   0
# 23518                [Fernando Bolaèos, Kattia Gonzèlez]                   0
# 23525  [Seong-woo Bae, Eui-sung Kim, Ah-sung Ko, Sung...                   1
#
#             title                                           fullplot  \
# 13         Salomè  Salome, the daughter of Herodias, seduces her ...
# 23             It  Shopgirl Betty Lou has designs on Cyrus Waltha...
# 24        Sunrise  In this fable-morality subtitled "A Song of Tw...
# 26       Upstream  Among the residents of a theatrical boarding h...
# 27          Wings  Two young men fall in love with the same same ...
# ...           ...                                                ...
# 23506          An  The "manager" of a pancake stall finds himself...
# 23507         Ivy  When the ship's owner goes bankrupt, the crew ...
# 23515  Marguerite                                                NaN
# 23518       Viaje                                                NaN
# 23525      Office  Kim Byong-gook works as section chief in big b...
#
#         languages   released  ...  \
# 13            NaN 1923-02-15  ...
# 23            NaN 1927-02-15  ...
# 24            NaN 1927-11-04  ...
# 26      [English] 1927-01-30  ...
# 27      [English] 1929-01-05  ...
# ...           ...        ...  ...
# 23506  [Japanese] 2015-05-30  ...
# 23507   [Turkish] 2015-01-26  ...
# 23515    [French]        NaT  ...
# 23518   [Spanish] 2015-04-16  ...
# 23525    [Korean] 2015-08-27  ...
#
#                                                   awards  \
# 13       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 23       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 24     {'wins': 5, 'nominations': 1, 'text': 'Won 3 O...
# 26       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 27     {'wins': 5, 'nominations': 1, 'text': 'Won 2 O...
# ...                                                  ...
# 23506  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 23507  {'wins': 1, 'nominations': 3, 'text': '1 win &...
# 23515  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 23518  {'wins': 0, 'nominations': 2, 'text': '2 nomin...
# 23525  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
#
#                          lastupdated  year  \
# 13     2015-04-26 00:03:19.913000000  1922
# 23     2015-08-06 00:01:15.977000000  1927
# 24     2015-09-12 00:26:13.493000000  1927
# 26     2015-06-20 00:36:05.633000000  1927
# 27     2015-09-02 00:36:34.413000000  1927
# ...                              ...   ...
# 23506  2015-08-27 00:14:54.743000000  2015
# 23507  2015-08-05 00:14:34.537000000  2015
# 23515  2015-09-17 04:45:55.677000000  2015
# 23518  2015-08-22 01:09:37.843000000  2015
# 23525  2015-08-14 00:12:17.177000000  2015
#
#                                                imdb  \
# 13       {'rating': 6.6, 'votes': 466, 'id': 13571}
# 23      {'rating': 7.5, 'votes': 2025, 'id': 18033}
# 24     {'rating': 8.4, 'votes': 24480, 'id': 18455}
# 26       {'rating': 6.2, 'votes': 179, 'id': 18530}
# 27      {'rating': 7.8, 'votes': 7196, 'id': 18578}
# ...                                             ...
# 23506  {'rating': 7.4, 'votes': 172, 'id': 4298958}
# 23507   {'rating': 7.6, 'votes': 48, 'id': 4309356}
# 23515   {'rating': 7.3, 'votes': 98, 'id': 4428788}
# 23518   {'rating': 6.9, 'votes': 28, 'id': 4543804}
# 23525   {'rating': 5.7, 'votes': 37, 'id': 4682562}
#
#                                countries   type  \
# 13                                 [USA]  movie
# 23                                 [USA]  movie
# 24                                 [USA]  movie
# 26                                 [USA]  movie
# 27                                 [USA]  movie
# ...                                  ...    ...
# 23506           [Japan, France, Germany]  movie
# 23507                  [Turkey, Germany]  movie
# 23515  [Czech Republic, Belgium, France]  movie
# 23518                       [Costa Rica]  movie
# 23525                      [South Korea]  movie
#
#                                                 tomatoes  \
# 13     {'viewer': {'rating': 3.9, 'numReviews': 310, ...
# 23     {'viewer': {'rating': 3.7, 'numReviews': 4599,...
# 24     {'viewer': {'rating': 4.4, 'numReviews': 9134,...
# 26     {'viewer': {'rating': 3.5, 'numReviews': 6}, '...
# 27     {'viewer': {'rating': 3.8, 'numReviews': 3316,...
# ...                                                  ...
# 23506                                                NaN
# 23507                                                NaN
# 23515                                                NaN
# 23518                                                NaN
# 23525                                                NaN
#
#                                                   poster  \
# 13     https://m.media-amazon.com/images/M/MV5BMjA0MT...
# 23     https://m.media-amazon.com/images/M/MV5BMTAxNT...
# 24     https://m.media-amazon.com/images/M/MV5BNDVkYm...
# 26                                                   NaN
# 27     https://m.media-amazon.com/images/M/MV5BYTI1Yj...
# ...                                                  ...
# 23506  https://m.media-amazon.com/images/M/MV5BMjIxOT...
# 23507  https://m.media-amazon.com/images/M/MV5BMTUyNz...
# 23515                                                NaN
# 23518                                                NaN
# 23525  https://m.media-amazon.com/images/M/MV5BZTA0ND...
#
#                                                  writers metacritic
# 13      [Oscar Wilde (play), Natacha Rambova (scenario)]        NaN
# 23     [Elinor Glyn (story), Hope Loring (screen play...        NaN
# 24     [Carl Mayer (scenario), Hermann Sudermann (fro...        NaN
# 26                 [Randall Faye, Wallace Smith (story)]        NaN
# 27     [John Monk Saunders (story), Hope Loring (scre...        NaN
# ...                                                  ...        ...
# 23506  [Durian Sukegawa (based on the novel by), Naom...        NaN
# 23507                                  [Tolga Karaèelik]        NaN
# 23515  [Xavier Giannoli, Marcia Romano (collaborating...        NaN
# 23518                                                NaN        NaN
# 23525                                                NaN        NaN
#
# [4793 rows x 22 columns]

# %% [markdown]
# Pick all movies that match following criteria:
#
# * imdb.rating is at least 7
# * genres does not contain "Crime" or "Horror"
# * rated is either "PG" or "G"

# %%
rate_bool =[]
for i in [c['rating'] for c in [x for x in movies_df.loc[:,'imdb']]]:
    if i == '':
        i=0
    rate_bool.append(i>7)

genre_bool = []
for movie in [mov for mov in movies_df.loc[:,'genres']]:
    if type(movie) == float:
        movie =[]
    genre_bool.append(('Horror' in movie) | ('Crime' in movie))


rated_bool = [(m in ['PG','G']) for m in movies_df.loc[:,'rated']]

# %%
movies_df[np.multiply(np.multiply(rate_bool,genre_bool),rated_bool)]
# Out:
#                             _id  \
# 775    573a1393f29313caabcde008
# 1146   573a1394f29313caabcdf81b
# 2174   573a1395f29313caabce2ffd
# 2256   573a1395f29313caabce321b
# 2412   573a1396f29313caabce443f
# 2468   573a1396f29313caabce4efc
# 2482   573a1396f29313caabce50f1
# 2499   573a1396f29313caabce34c4
# 2625   573a1396f29313caabce4f40
# 2634   573a1396f29313caabce518f
# 2639   573a1396f29313caabce5265
# 2798   573a1396f29313caabce4ed3
# 2803   573a1396f29313caabce4f7f
# 2804   573a1396f29313caabce4fe6
# 2956   573a1396f29313caabce4a94
# 2991   573a1396f29313caabce5159
# 2999   573a1396f29313caabce5268
# 3059   573a1396f29313caabce577b
# 3198   573a1397f29313caabce5fae
# 3280   573a1397f29313caabce62a4
# 3342   573a1397f29313caabce6681
# 3458   573a1397f29313caabce6b68
# 3556   573a1397f29313caabce6cab
# 3559   573a1397f29313caabce6ddc
# 3672   573a1397f29313caabce73ea
# 3740   573a1397f29313caabce7849
# 3869   573a1397f29313caabce7eb7
# 4198   573a1397f29313caabce867c
# 4421   573a1398f29313caabce913d
# 4489   573a1398f29313caabce8e2a
# 4680   573a1398f29313caabce944e
# 4683   573a1398f29313caabce9497
# 4849   573a1398f29313caabce9ad0
# 5278   573a1398f29313caabceae04
# 5357   573a1398f29313caabceb35c
# 9669   573a13a0f29313caabd04202
# 22839  573a13e7f29313caabdc8bb0
#
#                                                     plot  \
# 775    Two young men strangle their "inferior" classm...
# 1146   An ex-tennis pro carries out a plot to murder ...
# 2174   A man refuses to conform to life in a rural pr...
# 2256   In 1942, in Warsaw, a Polish prostitute is mur...
# 2412   One of the first films about the mafia occurre...
# 2468   Released from prison apparently under a New Ye...
# 2482   A year after Sheila is killed in a hit-and-run...
# 2499   An all guts, no glory San Francisco cop become...
# 2625   A man, his wife, and their friend, stage a blo...
# 2634   During the Great Depression, a con man finds h...
# 2639   In Chicago in September 1936, a young con man ...
# 2798   An impressionable teen girl from a dead-end to...
# 2803   A professional assassin codenamed "Jackal" plo...
# 2804   A short Arizona motorcycle cop gets his wish a...
# 2956   A recently released ex-con and his loyal wife ...
# 2991   Lucienne Delamare and Pierre Maury are having ...
# 2999   A black man plays Uncle Tom in order to gain a...
# 3059   Inspector Clouseau is put on the case when the...
# 3198   A detective (inspector Rogas) is assigned to i...
# 3280   Charles Dreyfus threatens to destroy the world...
# 3342   Belle Duke, in order to get revenge on her for...
# 3458   As Hercule Poirot enjoys a luxurious cruise do...
# 3556   In San Francisco, a group of people discover t...
# 3559                                                 NaN
# 3672   Jonathan and Lucy live in Wismar and the Count...
# 3740   When a young boy's family is killed by the mob...
# 3869   Kermit, Gonzo and Fozzie are reporters who tra...
# 4198     A family's home is haunted by a host of ghosts.
# 4421   A boy inadvertantly breaks 3 important rules c...
# 4489   Claude Massoulier is murdered while hunting at...
# 4680   An African American officer investigates a mur...
# 4683   A night at the movies turns into a nightmare w...
# 4849   Two Scottish friends become local folk heroes ...
# 5278   Two con men try to settle their rivalry by bet...
# 5357   A toon hating detective is a cartoon rabbit's ...
# 9669   Jonathan and Lucy live in Wismar and the Count...
# 22839  An aged, retired Sherlock Holmes looks back on...
#
#                            genres  runtime  \
# 775      [Crime, Drama, Thriller]     80.0
# 1146            [Crime, Thriller]    105.0
# 2174               [Crime, Drama]    126.0
# 2256      [Crime, Drama, Mystery]    148.0
# 2412               [Crime, Drama]    101.0
# 2468              [Comedy, Crime]     90.0
# 2482      [Crime, Drama, Mystery]    120.0
# 2499     [Action, Crime, Mystery]    114.0
# 2625       [Action, Crime, Drama]    111.0
# 2634       [Comedy, Crime, Drama]    102.0
# 2639       [Comedy, Crime, Drama]    129.0
# 2798               [Crime, Drama]     94.0
# 2803     [Crime, Drama, Thriller]    143.0
# 2804      [Crime, Drama, Mystery]    114.0
# 2956    [Action, Crime, Thriller]    122.0
# 3672   Jonathan Harker is sent away to Count Dracula'...
# 3740   Mild mannered Jack Dawn has been secretly work...
# 3869   Kermit and Fozzie are newspaper reporters sent...
# 4198   A young family are visited by ghosts in their ...
# 4421   Minature green monsters tear through the small...
# 4489   Claude Massoulier is murdered while hunting at...
# 4680   A black soldier is killed while returning to h...
# 4683   Michael Jackson and his date are watching a mo...
# 4849   Two lads in Edinburgh embark on a non-violent ...
# 5278   Lawrence and Freddie are con-men; big-time and...
# 5357   'Toon star Roger is worried that his wife Jess...
# 9669   Jonathan Harker is sent away to Count Dracula'...
# 22839  The story is set in 1947, following a long-ret...
#
#                                  languages   released  ...  \
# 775                              [English] 1948-08-28  ...
# 1146                             [English] 1954-05-29  ...
# 2174                             [English] 1967-11-01  ...
# 2256   [English, Italian, Spanish, French] 1967-02-24  ...
# 2412                             [Italian] 1971-03-26  ...
# 2468                              [French] 1973-04-13  ...
# 2482                     [English, French] 1973-06-14  ...
# 2499                             [English] 1968-10-17  ...
# 2625                             [English]        NaT  ...
# 2634                             [English] 1973-05-09  ...
# 2639                             [English] 1973-12-26  ...
# 2798                    [English, Spanish] 1974-01-05  ...
# 2803            [English, Italian, French] 1973-07-30  ...
# 2804                             [English] 1973-10-04  ...
# 2956                    [English, Spanish] 1972-12-13  ...
# 2991                              [French] 1973-04-12  ...
# 2999                             [English] 1981-12-23  ...
# 3059                             [English] 1975-05-21  ...
# 3198                             [Italian] 1976-02-12  ...
# 3280                             [English] 1976-12-15  ...
# 3342                             [Italian] 1981-04-01  ...
# 3458     [English, French, Arabic, German] 1978-09-29  ...
# 3556                             [English] 1978-12-20  ...
# 3559                     [Italian, French] 1978-10-28  ...
# 3672             [German, English, Romany] 1979-01-17  ...
# 3740                             [English] 1980-09-19  ...
# 3869                             [English] 1981-06-26  ...
# 4198                             [English] 1982-06-04  ...
# 4421                    [English, Spanish] 1984-06-08  ...
# 4489                              [French] 1983-08-10  ...
# 4680                             [English] 1984-11-02  ...
# 4683                             [English] 1983-12-02  ...
# 4849                             [English] 1986-09-12  ...
# 5278                             [English] 1988-12-14  ...
# 5357                             [English] 1988-06-22  ...
# 9669             [German, English, Romany] 1979-01-17  ...
# 22839          [English, Japanese, French] 2015-07-17  ...
#
#                                                   awards  \
# 775    {'wins': 0, 'nominations': 3, 'text': '3 nomin...
# 1146   {'wins': 4, 'nominations': 2, 'text': 'Nominat...
# 2174   {'wins': 6, 'nominations': 6, 'text': 'Won 1 O...
# 2256     {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2412   {'wins': 2, 'nominations': 1, 'text': '2 wins ...
# 2468   {'wins': 4, 'nominations': 1, 'text': '4 wins ...
# 2482     {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2499   {'wins': 10, 'nominations': 6, 'text': 'Won 1 ...
# 2625   {'wins': 0, 'nominations': 2, 'text': 'Won 1 B...
# 2634   {'wins': 8, 'nominations': 10, 'text': 'Won 1 ...
# 2639   {'wins': 17, 'nominations': 6, 'text': 'Won 7 ...
# 2798   {'wins': 4, 'nominations': 0, 'text': 'Nominat...
# 2803   {'wins': 2, 'nominations': 10, 'text': 'Nomina...
# 2804   {'wins': 0, 'nominations': 2, 'text': 'Nominat...
# 2956   {'wins': 2, 'nominations': 0, 'text': 'Nominat...
# 2991   {'wins': 1, 'nominations': 1, 'text': '1 win &...
# 2999     {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3059   {'wins': 5, 'nominations': 2, 'text': 'Nominat...
# 3198   {'wins': 5, 'nominations': 6, 'text': '5 wins ...
# 3280   {'wins': 3, 'nominations': 2, 'text': 'Nominat...
# 3342     {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3458   {'wins': 5, 'nominations': 5, 'text': 'Won 1 O...
# 3556   {'wins': 4, 'nominations': 9, 'text': '4 wins ...
# 3559     {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3672   {'wins': 5, 'nominations': 8, 'text': '5 wins ...
# 3740   {'wins': 5, 'nominations': 1, 'text': 'Nominat...
# 3869   {'wins': 0, 'nominations': 2, 'text': 'Nominat...
# 4198   {'wins': 7, 'nominations': 4, 'text': 'Nominat...
# 4421   {'wins': 7, 'nominations': 6, 'text': '7 wins ...
# 4489   {'wins': 0, 'nominations': 3, 'text': 'Nominat...
# 4680   {'wins': 8, 'nominations': 6, 'text': 'Nominat...
# 4683    {'wins': 2, 'nominations': 0, 'text': '2 wins.'}
# 4849   {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 5278   {'wins': 2, 'nominations': 0, 'text': 'Nominat...
# 5357   {'wins': 22, 'nominations': 21, 'text': 'Won 3...
# 9669   {'wins': 5, 'nominations': 8, 'text': '5 wins ...
# 22839  {'wins': 1, 'nominations': 1, 'text': '1 win &...
#
#                          lastupdated  year  \
# 775    2015-09-06 00:54:06.103000000  1948
# 1146   2015-09-04 00:36:36.117000000  1954
# 2174   2015-09-04 00:33:43.757000000  1967
# 2256   2015-08-22 00:17:45.890000000  1967
# 2412   2015-08-13 00:10:10.397000000  1971
# 2468   2015-08-14 01:00:06.003000000  1973
# 2482   2015-09-02 00:00:53.320000000  1973
# 2499   2015-09-07 00:08:54.533000000  1968
# 2625   2015-09-12 00:01:38.777000000  1973
# 2634   2015-09-02 00:24:07.990000000  1973
# 2639   2015-09-05 00:01:35.660000000  1973
# 2798   2015-08-18 00:13:05.093000000  1973
# 2803   2015-08-21 00:42:34.783000000  1973
# 2804   2015-08-13 00:28:07.723000000  1973
# 2956   2015-09-12 00:27:28.090000000  1972
# 2991   2015-08-21 00:01:43.923000000  1973
# 2999   2015-09-15 03:36:29.980000000  1973
# 3059   2015-08-19 00:46:50.937000000  1975
# 3198   2015-07-12 00:31:06.280000000  1976
# 3280   2015-09-15 04:11:57.200000000  1976
# 3342   2015-09-17 04:41:25.397000000  1976
# 3458   2015-09-12 00:32:17.430000000  1978
# 3556   2015-09-13 00:04:16.797000000  1978
# 3559   2015-07-28 00:35:21.823000000  1978
# 3672   2015-09-16 10:54:04.087000000  1979
# 3740   2015-08-24 00:40:38.993000000  1980
# 3869   2015-09-03 00:29:12.240000000  1981
# 4198   2015-09-07 00:17:55.617000000  1982
# 4421   2015-09-05 00:00:44.033000000  1984
# 4489   2015-08-13 00:40:02.003000000  1983
# 4680   2015-08-13 01:03:34.567000000  1984
# 4683   2015-09-11 00:43:01.960000000  1983
# 4849   2015-07-22 00:53:21.047000000  1985
# 5278   2015-08-24 01:02:36.353000000  1988
# 5357   2015-09-13 00:26:06.120000000  1988
# 9669   2015-08-30 04:39:17.020000000  1979
# 22839  2015-09-10 17:50:35.553000000  2015
#
#                                                 imdb               countries  \
# 775     {'rating': 8.0, 'votes': 88618, 'id': 40746}                   [USA]
# 1146    {'rating': 8.2, 'votes': 93546, 'id': 46912}                   [USA]
# 2174   {'rating': 8.2, 'votes': 109282, 'id': 61512}                   [USA]
# 2256     {'rating': 7.4, 'votes': 4350, 'id': 62038}            [UK, France]
# 2412      {'rating': 7.2, 'votes': 704, 'id': 66940}                 [Italy]
# 2468      {'rating': 7.3, 'votes': 829, 'id': 69815}         [France, Italy]
# 2482     {'rating': 7.4, 'votes': 3191, 'id': 70291}                   [USA]
# 2499    {'rating': 7.5, 'votes': 43049, 'id': 62765}                   [USA]
# 2625     {'rating': 7.5, 'votes': 7035, 'id': 69865}                   [USA]
# 2634    {'rating': 8.2, 'votes': 21470, 'id': 70510}                   [USA]
# 2639   {'rating': 8.4, 'votes': 157525, 'id': 70735}                   [USA]
# 2798    {'rating': 7.9, 'votes': 42455, 'id': 69762}                   [USA]
# 2803    {'rating': 7.8, 'votes': 27372, 'id': 69947}            [UK, France]
# 2804     {'rating': 7.2, 'votes': 3355, 'id': 70022}                   [USA]
# 2956    {'rating': 7.5, 'votes': 19487, 'id': 68638}                   [USA]
# 2991      {'rating': 7.3, 'votes': 945, 'id': 70453}         [France, Italy]
# 2999      {'rating': 7.2, 'votes': 740, 'id': 70726}                   [USA]
# 3059    {'rating': 7.1, 'votes': 18310, 'id': 72081}                    [UK]
# 3198     {'rating': 7.4, 'votes': 1067, 'id': 74262}         [Italy, France]
# 3280    {'rating': 7.2, 'votes': 20769, 'id': 75066}               [UK, USA]
# 3342     {'rating': 7.6, 'votes': 1679, 'id': 76101}                 [Italy]
# 3458    {'rating': 7.2, 'votes': 18077, 'id': 77413}                    [UK]
# 3556    {'rating': 7.4, 'votes': 34043, 'id': 77745}                   [USA]
# 3559     {'rating': 7.2, 'votes': 4323, 'id': 78058}                 [Italy]
# 3672    {'rating': 7.6, 'votes': 21537, 'id': 79641}  [West Germany, France]
# 3740     {'rating': 7.1, 'votes': 5613, 'id': 80798}                   [USA]
# 3869     {'rating': 7.2, 'votes': 9158, 'id': 82474}               [UK, USA]
# 4198    {'rating': 7.4, 'votes': 94447, 'id': 84516}                   [USA]
# 4421   {'rating': 7.2, 'votes': 125839, 'id': 87363}                   [USA]
# 4489     {'rating': 7.4, 'votes': 3890, 'id': 86551}                [France]
# 4680     {'rating': 7.2, 'votes': 6172, 'id': 88146}                   [USA]
# 4683    {'rating': 8.6, 'votes': 10458, 'id': 88263}                   [USA]
# 4849      {'rating': 7.2, 'votes': 912, 'id': 89904}                    [UK]
# 5278    {'rating': 7.3, 'votes': 47252, 'id': 95031}                   [USA]
# 5357   {'rating': 7.7, 'votes': 127268, 'id': 96438}                   [USA]
# 9669    {'rating': 7.6, 'votes': 21413, 'id': 79641}  [West Germany, France]
# 22839  {'rating': 7.4, 'votes': 8033, 'id': 3168230}               [UK, USA]
#
#         type                                           tomatoes  \
# 775    movie  {'viewer': {'rating': 4.0, 'numReviews': 38062...
# 1146   movie  {'viewer': {'rating': 3.9, 'numReviews': 37269...
# 2174   movie  {'viewer': {'rating': 4.1, 'numReviews': 62369...
# 2256   movie  {'viewer': {'rating': 3.7, 'numReviews': 981, ...
# 2412   movie  {'viewer': {'rating': 3.5, 'numReviews': 141, ...
# 2468   movie  {'viewer': {'rating': 3.9, 'numReviews': 274, ...
# 2482   movie  {'viewer': {'rating': 3.8, 'numReviews': 1361,...
# 2499   movie  {'viewer': {'rating': 3.8, 'numReviews': 39414...
# 2625   movie  {'viewer': {'rating': 3.7, 'numReviews': 3047,...
# 2634   movie  {'viewer': {'rating': 4.1, 'numReviews': 11037...
# 2639   movie  {'viewer': {'rating': 4.1, 'numReviews': 60591...
# 2798   movie  {'viewer': {'rating': 4.1, 'numReviews': 24817...
# 2803   movie  {'viewer': {'rating': 3.9, 'numReviews': 8717,...
# 2804   movie  {'viewer': {'rating': 3.6, 'numReviews': 2327,...
# 2956   movie  {'viewer': {'rating': 3.7, 'numReviews': 9479,...
# 2991   movie  {'viewer': {'rating': 3.8, 'numReviews': 305, ...
# 2999   movie  {'viewer': {'rating': 3.9, 'numReviews': 1067,...
# 3059   movie  {'viewer': {'rating': 3.4, 'numReviews': 41317...
# 3198   movie  {'viewer': {'rating': 3.7, 'numReviews': 399, ...
# 3280   movie  {'viewer': {'rating': 3.4, 'numReviews': 37731...
# 3342   movie  {'viewer': {'rating': 1.6, 'numReviews': 19}, ...
# 3458   movie  {'viewer': {'rating': 3.5, 'numReviews': 8382,...
# 3556   movie  {'viewer': {'rating': 3.4, 'numReviews': 34353...
# 3559   movie  {'viewer': {'rating': 2.4, 'numReviews': 589, ...
# 3672   movie  {'viewer': {'rating': 3.8, 'numReviews': 20719...
# 3740   movie  {'viewer': {'rating': 3.7, 'numReviews': 4591,...
# 3869   movie  {'viewer': {'rating': 3.4, 'numReviews': 35030...
# 4198   movie  {'viewer': {'rating': 3.4, 'numReviews': 18076...
# 4421   movie                                                NaN
# 4489   movie                                                NaN
# 4680   movie                                                NaN
# 4683   movie                                                NaN
# 4849   movie                                                NaN
# 5278   movie  {'viewer': {'rating': 3.4, 'numReviews': 48099...
# 5357   movie  {'viewer': {'rating': 3.5, 'numReviews': 44035...
# 9669   movie  {'viewer': {'rating': 3.8, 'numReviews': 20719...
# 22839  movie                                                NaN
#
#                                                   poster  \
# 775    https://m.media-amazon.com/images/M/MV5BYWFjMD...
# 2634   [Joe David Brown (novel), Alvin Sargent (scree...        NaN
# 2639                                     [David S. Ward]        NaN
# 2798                                   [Terrence Malick]       90.0
# 2803   [Frederick Forsyth (book), Kenneth Ross (scree...        NaN
# 2804   [Robert Boris (screenplay), Robert Boris (stor...        NaN
# 2956    [Walter Hill (screenplay), Jim Thompson (novel)]        NaN
# 2991     [Aeschylus (opening quotation), Claude Chabrol]        NaN
# 2999   [Sam Greenlee (screenplay), Melvin Clay (scree...        NaN
# 3059   [Frank Waldman (screenplay), Blake Edwards (sc...        NaN
# 3198   [Francesco Rosi (screenplay), Tonino Guerra (s...        NaN
# 3280   [Frank Waldman (screenplay), Blake Edwards (sc...        NaN
# 3342   [Massimo De Rita (screenplay), Sergio Corbucci...        NaN
# 3458                      [Anthony Shaffer (screenplay)]        NaN
# 3556    [Jack Finney (novel), W.D. Richter (screenplay)]        NaN
# 3559   [Mario Amendola (story), Bruno Corbucci (story...        NaN
# 3672                                     [Werner Herzog]        NaN
# 3740                                   [John Cassavetes]        NaN
# 3869   [Tom Patchett, Jay Tarses, Jerry Juhl, Jack Rose]        NaN
# 4198   [Steven Spielberg (screenplay), Michael Grais ...       79.0
# 4421                                    [Chris Columbus]        NaN
# 4489   [Charles Williams (novel), Franèois Truffaut, ...        NaN
# 4680   [Charles Fuller (screenplay), Charles Fuller (...        NaN
# 4683                      [John Landis, Michael Jackson]        NaN
# 4849                                    [Ninian Dunnett]        NaN
# 5278        [Dale Launer, Stanley Shapiro, Paul Henning]       68.0
# 5357   [Gary K. Wolf (novel), Jeffrey Price (screenpl...       83.0
# 9669                                     [Werner Herzog]        NaN
# 22839  [Mitch Cullin (novel), Jeffrey Hatcher (screen...       67.0
#
# [37 rows x 22 columns]

# %% [markdown]
# ## Citibike Data

# %% [markdown]
# How many trips in the sample_training.trips collection started at stations that are to
# the west of the -74 longitude coordinate?
# Longitude decreases in value as you move west.

# %%
db = client.get_database('sample_training')
trips = db.trips.find()
trips_df = pd.DataFrame(trips)
trips_df
# Out:
#                            _id  tripduration  start station id  \
# 0     572bb8222b288919b68abf5c           589               489
# 1     572bb8222b288919b68abf61          1376               527
# 2     572bb8222b288919b68abf63           615               432
# 3     572bb8222b288919b68abf64          1770              3226
# 4     572bb8222b288919b68abf6e           719              3116
# ...                        ...           ...               ...
# 9995  572bb8232b288919b68b1c15           415               457
# 9996  572bb8232b288919b68b1c1b           268               304
# 9997  572bb8232b288919b68b1c27          1319              3235
# 9998  572bb8232b288919b68b1c44           566               442
# 9999  572bb8232b288919b68b1c48           552               438
#
#                start station name  end station id         end station name  \
# 0                10 Ave & W 28 St             284    Greenwich Ave & 8 Ave
# 1                 E 33 St & 2 Ave             259  South St & Whitehall St
# 2               E 7 St & Avenue A             311   Norfolk St & Broome St
# 3     W 82 St & Central Park West             509          9 Ave & W 22 St
# 4          Huron St & Franklin St            3126      44 Dr & Jackson Ave
# ...                           ...             ...                      ...
# 9995           Broadway & W 58 St            3164   Columbus Ave & W 72 St
# 9996        Broadway & Battery Pl             363           West Thames St
# 9997        E 41 St & Madison Ave             490          8 Ave & W 33 St
# 9998              W 27 St & 7 Ave             380         W 4 St & 7 Ave S
# 9999          St Marks Pl & 1 Ave             536          1 Ave & E 30 St
#
#       bikeid    usertype birth year  \
# 0      21997  Subscriber       1982
# 1      23933  Subscriber       1963
# 2      23993  Subscriber       1971
# 3      22541  Subscriber       1970
# 4      16624  Subscriber       1982
# ...      ...         ...        ...
# 9995   22736  Subscriber       1966
# 9996   18736  Subscriber       1960
# 9997   24227    Customer
# 9998   15101  Subscriber       1988
# 9999   23575  Subscriber       1992
#
#                                  start station location  \
# 0     {'type': 'Point', 'coordinates': [-74.00176802...
# 1     {'type': 'Point', 'coordinates': [-73.976056, ...
# 2     {'type': 'Point', 'coordinates': [-73.98379855...
# 3     {'type': 'Point', 'coordinates': [-73.97137, 4...
# 4     {'type': 'Point', 'coordinates': [-73.95826, 4...
# ...                                                 ...
# 9995  {'type': 'Point', 'coordinates': [-73.98169333...
# 9996  {'type': 'Point', 'coordinates': [-74.01361706...
# 9997  {'type': 'Point', 'coordinates': [-73.97992193...
# 9998  {'type': 'Point', 'coordinates': [-73.993915, ...
# 9999  {'type': 'Point', 'coordinates': [-73.98564945...
#
#                                    end station location          start time  \
# 0     {'type': 'Point', 'coordinates': [-74.00263761... 2016-01-01 00:00:48
# 1     {'type': 'Point', 'coordinates': [-74.01234218... 2016-01-01 00:03:12
# 2     {'type': 'Point', 'coordinates': [-73.98802084... 2016-01-01 00:03:43
# 3     {'type': 'Point', 'coordinates': [-74.00197139... 2016-01-01 00:04:43
# 4     {'type': 'Point', 'coordinates': [-73.9432635,... 2016-01-01 00:10:00
# ...                                                 ...                 ...
# 9995  {'type': 'Point', 'coordinates': [-73.97898475... 2016-01-02 19:29:04
# 9996  {'type': 'Point', 'coordinates': [-74.01713445... 2016-01-02 19:29:48
# 9997  {'type': 'Point', 'coordinates': [-73.993934, ... 2016-01-02 19:30:19
# 9998  {'type': 'Point', 'coordinates': [-74.00293877... 2016-01-02 19:33:16
# 9999  {'type': 'Point', 'coordinates': [-73.97536082... 2016-01-02 19:34:07
#
#                stop time
# 0    2016-01-01 00:10:37
# 1    2016-01-01 00:26:09
# 2    2016-01-01 00:13:59
# 3    2016-01-01 00:34:14
# 4    2016-01-01 00:21:59
# ...                  ...
# 9995 2016-01-02 19:35:59
# 9996 2016-01-02 19:34:16
# 9997 2016-01-02 19:52:19
# 9998 2016-01-02 19:42:42
# 9999 2016-01-02 19:43:19
#
# [10000 rows x 13 columns]

# %%
trips_df[[point['coordinates'][0]<(-74) for point in trips_df['start station location']]].count()[0]
# Out:
# 1928

# %% [markdown]
# What is the difference between the number of people born in 1998 and the number of
# people born after 1998 in the sample_training.trips collection?

# %%
pd.DataFrame( [sum(trips_df['birth year'][trips_df['birth year']!='']>1998),sum(trips_df['birth year'][trips_df['birth year']!='']==1998)],index=['after 1998', 'at 1998'], columns=['Value'])
# Out:
#             Value
# after 1998     18
# at 1998        12
